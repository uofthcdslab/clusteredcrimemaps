# %%
import pandas as pd
import os

# %%
file_list = []
for file in os.listdir("./CrimeData"):
    if file.endswith(".xls"):
        data = pd.read_excel("./CrimeData/" + file)
        file_list.append(data)
df = pd.concat(file_list, ignore_index=True)
df.columns
# Out:
# Index(['INCIDENT_N', 'CDATE', 'CTIME', 'POLICE_DISTRICT', 'OFFENSE1',
#        'OFFENSE2', 'OFFENSE3', 'OFFENSE4', 'OFFENSE5', 'LOCATION'],
#       dtype='object')

# %%
columns = ['Incident Number','Date', 'Time', 'Police District','Offense 1',
          'Offense 2', 'Offense 3', 'Offense 4', 'Offense 5', 'Location']
df.columns = columns
df = df[df['Offense 1'].notnull()]
df = df[df['Location'].notnull()]

count_1 = df['Offense 1'].value_counts()
count_2 = df['Offense 2'].value_counts()
count_3 = df['Offense 3'].value_counts()
count_4 = df['Offense 4'].value_counts()
count_5 = df['Offense 5'].value_counts()

counts = [count_1, count_2, count_3, count_4, count_5]
for count in counts:
    if count.empty:
        df = df.drop(count.name, axis = 1)

df.to_csv('./CrimeData/CompleteData.csv', sep=';', index = False)

# %%
zipped = zip(df['Offense 1'].items(), df['Offense 2'].items(), 
             df['Offense 3'].items())
keyword = 'theft'

for off_1, off_2, off_3 in zipped:
    if((not keyword in off_1[1].lower() and
        pd.isnull(off_2[1]) and
        pd.isnull(off_3[1])) 
       
       or
       
       (not keyword in off_1[1].lower() and
        not keyword in off_2[1].lower() and
        pd.isnull(off_3[1])) 
       
       or
       
       (not keyword in off_1[1].lower() and 
        not keyword in off_2[1].lower() and 
        not keyword in off_3[1].lower())):
        
        df = df.drop(off_1[0])

# %%
import geocoder
import requests

df['Address'] = df['Location'].copy()

def address_to_latlong(address):
    address += ", Milwaukee WI, 53233"
    location = geocoder.arcgis(address, session = session)
    if not location.latlng:
        print("Couldn't Parse: "  + address )
    return location.latlng

with requests.Session() as session:
    df['Location'] = df['Location'].apply(address_to_latlong)

# %%
df.to_csv('./CrimeData/TheftData.csv', sep=';', index = False)

# %%
df
# Out:
#      Incident Number        Date      Time  Police District  \
# 0          150310032  01/31/2015  09:10 AM              7.0
# 2          150310059  01/31/2015  12:37 PM              7.0
# 8          150300044  01/30/2015  09:01 AM              7.0
# 11         150300111  01/30/2015  07:33 PM              7.0
# 13         150310007  01/30/2015  11:42 PM              7.0
# 15         150290077  01/29/2015  01:03 PM              7.0
# 16         150290079  01/29/2015  01:09 PM              7.0
# 17         150290085  01/29/2015  02:06 PM              7.0
# 18         150290159  01/29/2015  10:41 PM              4.0
# 22         150280037  01/28/2015  09:50 AM              4.0
# 26         150280090  01/28/2015  06:36 PM              7.0
# 27         150280094  01/28/2015  06:53 PM              4.0
# 29         150280136  01/28/2015  07:51 PM              5.0
# 33         150270104  01/27/2015  11:54 AM              7.0
# 35         150270156  01/27/2015  10:11 PM              7.0
# 36         150260029  01/26/2015  08:53 AM              4.0
# 41         150260098  01/26/2015  03:41 PM              4.0
# 42         150260133  01/26/2015  08:47 PM              5.0
# 45         150250026  01/25/2015  05:08 AM              4.0
# 47         150250053  01/25/2015  11:22 AM              7.0
# 51         150250072  01/25/2015  02:06 PM              4.0
# 52         150250073  01/25/2015  01:13 PM              7.0
# 56         150240013  01/24/2015  01:50 AM              7.0
# 66         150250004  01/24/2015  11:55 PM              7.0
# 68         150230117  01/23/2015  07:48 PM              7.0
# 70         150220010  01/22/2015  03:59 AM              5.0
# 71         150220011  01/22/2015  04:32 AM              5.0
# 72         150220074  01/22/2015  05:49 PM              5.0
# 78         150210019  01/21/2015  06:09 AM              4.0
# 79         150210042  01/21/2015  07:48 AM              7.0
# ...              ...         ...       ...              ...
# 2808       150220059  01/22/2015  02:03 PM              4.0
# 2810       150220066  01/22/2015  02:48 PM              4.0
# 2813       150220105  01/22/2015  09:19 PM              4.0
# 2826       150200115  01/20/2015  06:10 PM              4.0
# 2837       150180112  01/18/2015  06:19 PM              4.0
# 2840       150170045  01/17/2015  09:35 AM              4.0
# 2842       150170069  01/17/2015  12:54 PM              4.0
# 2843       150170079  01/17/2015  04:38 PM              4.0
# 2847       150160091  01/16/2015  01:47 PM              4.0
# 2849       150160118  01/16/2015  05:35 PM              4.0
# 2858       150150150  01/15/2015  11:58 PM              4.0
# 2859       150140074  01/14/2015  02:43 PM              4.0
# 2861       150140117  01/14/2015  06:56 PM              4.0
# 2874       150110117  01/11/2015  11:31 PM              4.0
# 2876       150100053  01/10/2015  03:31 PM              4.0
# 2885       150080034  01/08/2015  01:17 PM              4.0
# 2888       150070104  01/07/2015  09:10 PM              4.0
# 2889       150060122  01/06/2015  09:21 PM              4.0
# 2891       150050030  01/05/2015  09:52 AM              4.0
# 2892       150050054  01/05/2015  01:51 PM              4.0
# 2895       150040066  01/04/2015  03:01 PM              4.0
# 2897       150040095  01/04/2015  08:03 PM              4.0
# 2898       150020078  01/03/2015  02:22 AM              4.0
# 2902       150020033  01/02/2015  08:25 AM              4.0
# 2903       150020038  01/02/2015  10:06 AM              4.0
# 2904       150020049  01/02/2015  10:26 AM              4.0
# 2907       150020076  01/02/2015  10:56 AM              4.0
# 2911       150020162  01/02/2015  10:07 PM              4.0
# 2914       150010071  01/01/2015  09:58 AM              4.0
# 2915       150010082  01/01/2015  11:43 AM              4.0
#
#                                      Offense 1  \
# 0                          MOTOR VEHICLE THEFT
# 2                          MOTOR VEHICLE THEFT
# 8                          MOTOR VEHICLE THEFT
# 11                         MOTOR VEHICLE THEFT
# 13                         MOTOR VEHICLE THEFT
# 15                         MOTOR VEHICLE THEFT
# 16                         MOTOR VEHICLE THEFT
# 17                    THEFT FROM MOTOR VEHICLE
# 18    THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES
# 22                         MOTOR VEHICLE THEFT
# 26                         MOTOR VEHICLE THEFT
# 27                         MOTOR VEHICLE THEFT
# 29                         MOTOR VEHICLE THEFT
# 33                         MOTOR VEHICLE THEFT
# 35                    THEFT FROM MOTOR VEHICLE
# 36    THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES
# 41                         MOTOR VEHICLE THEFT
# 42    THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES
# 45                         MOTOR VEHICLE THEFT
# 47                         MOTOR VEHICLE THEFT
# 51                         MOTOR VEHICLE THEFT
# 52                         MOTOR VEHICLE THEFT
# 56                         MOTOR VEHICLE THEFT
# 66                         MOTOR VEHICLE THEFT
# 68                         MOTOR VEHICLE THEFT
# 70                         MOTOR VEHICLE THEFT
# 71                    THEFT FROM MOTOR VEHICLE
# 72                         THEFT FROM BUILDING
# 78    THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES
# 79                         MOTOR VEHICLE THEFT
# ...                                        ...
# 2808  THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES
# 2810                       MOTOR VEHICLE THEFT
# 2813  THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES
# 2826  THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES
# 2837                       MOTOR VEHICLE THEFT
# 2840                       MOTOR VEHICLE THEFT
# 2842                       THEFT FROM BUILDING
# 2843  THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES
# 2847                       THEFT FROM BUILDING
# 2849                       THEFT FROM BUILDING
# 2858                       MOTOR VEHICLE THEFT
# 2859                  THEFT FROM MOTOR VEHICLE
# 2861                       MOTOR VEHICLE THEFT
# 2874                       THEFT FROM BUILDING
# 2876                       MOTOR VEHICLE THEFT
# 2885                       THEFT FROM BUILDING
# 2888                  THEFT FROM MOTOR VEHICLE
# 2889                       MOTOR VEHICLE THEFT
# 2891                  THEFT FROM MOTOR VEHICLE
# 2892                       THEFT FROM BUILDING
# 2895                       MOTOR VEHICLE THEFT
# 2897                       MOTOR VEHICLE THEFT
# 2898                       MOTOR VEHICLE THEFT
# 2902  THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES
# 2903                       MOTOR VEHICLE THEFT
# 2904  THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES
# 2907                  THEFT FROM MOTOR VEHICLE
# 2911                       MOTOR VEHICLE THEFT
# 2914                       MOTOR VEHICLE THEFT
# 2915                       MOTOR VEHICLE THEFT
#
#                                      Offense 2 Offense 3  \
# 0                                          NaN       NaN
# 2                                          NaN       NaN
# 8                                          NaN       NaN
# 11                                         NaN       NaN
# 13                                         NaN       NaN
# 15                                         NaN       NaN
# 16                                         NaN       NaN
# 17                                         NaN       NaN
# 18                                         NaN       NaN
# 22                                         NaN       NaN
# 26                                         NaN       NaN
# 27                                         NaN       NaN
# 29                                         NaN       NaN
# 33                                         NaN       NaN
# 35                                         NaN       NaN
# 36                                         NaN       NaN
# 41                                         NaN       NaN
# 42                                         NaN       NaN
# 45                                         NaN       NaN
# 47                                         NaN       NaN
# 51                                         NaN       NaN
# 52                                         NaN       NaN
# 56                                         NaN       NaN
# 66                                         NaN       NaN
# 68                                         NaN       NaN
# 70                                         NaN       NaN
# 71                                         NaN       NaN
# 72                                         NaN       NaN
# 78                                         NaN       NaN
# 79                                         NaN       NaN
# ...                                        ...       ...
# 2808                                       NaN       NaN
# 2810                                       NaN       NaN
# 2813                                       NaN       NaN
# 2826                                       NaN       NaN
# 2837                                       NaN       NaN
# 2840                                       NaN       NaN
# 2842                                       NaN       NaN
# 2843                                       NaN       NaN
# 2847                                       NaN       NaN
# 2849                                       NaN       NaN
# 2858                                       NaN       NaN
# 2859                                       NaN       NaN
# 2861                                       NaN       NaN
# 2874                                       NaN       NaN
# 2876                                       NaN       NaN
# 2885                                       NaN       NaN
# 2888                                       NaN       NaN
# 2889                                       NaN       NaN
# 2891                                       NaN       NaN
# 2892                                       NaN       NaN
# 2895                                       NaN       NaN
# 2897                                       NaN       NaN
# 2898                                       NaN       NaN
# 2902                                       NaN       NaN
# 2903                                       NaN       NaN
# 2904                                       NaN       NaN
# 2907  THEFT OF MOTOR VEHICLE PARTS/ACCESSORIES       NaN
# 2911                                       NaN       NaN
# 2914                                       NaN       NaN
# 2915                                       NaN       NaN
#
#                                       Location                   Address
# 0      [43.11009438305041, -87.93795978781316]            5122 N 21ST ST
# 2      [43.10953822790799, -87.96358142524178]            5067 N 41ST ST
# 8     [43.105253731775406, -87.94286695384608]            4835 N 24TH PL
# 11     [43.10839663389862, -87.94865534037086]        5003 N TEUTONIA AV
# 13     [43.10449237562375, -87.93141233301196]       4803 N GREEN BAY AV
# 15     [43.10991858807347, -87.96374160079347]            5101 N 41ST ST
# 16    [43.104635799503626, -87.94668666145947]        4801 N TEUTONIA AV
# 17     [43.105574581103156, -87.9341052728393]            4857 N 19TH ST
# 18     [43.13035606917833, -87.95845059421879]            6163 N 37TH ST
# 22    [43.125910964020875, -87.95606732154886]            5966 N 35TH ST
# 26     [43.10221551073835, -87.93539606347679]            4685 N 19TH PL
# 27     [43.11789132172822, -87.95058007391049]     5541 N TEUTONIA AV #3
# 29     [43.09891533067906, -87.94083282677275]            2316 W RUBY AV
# 33     [43.10527045646751, -87.97889313131219]            4828 N 53RD ST
# 35     [43.10823182593913, -87.95198219432206]       3126 W FAIRMOUNT AV
# 36     [43.11695533791959, -87.95757197996215]            5479 N 36TH ST
# 41    [43.114486538823826, -87.95020832835093]        5335 N TEUTONIA AV
# 42     [43.09085504982181, -87.94090282550422]            4073 N 23RD ST
# 45     [43.11263940688423, -87.95006853053746]        5233 N TEUTONIA AV
# 47     [43.11093359620958, -87.93446724546624]            5144 N 19TH ST
# 51      [43.11490203909892, -87.9339713943636]       5385 N GREEN BAY AV
# 52     [43.03972542049286, -87.93670086195442]  4858 N MOTHER DANIELS WA
# 56     [43.10470748086664, -87.94672515783901]        4811 N TEUTONIA AV
# 66     [43.10741850875826, -87.93798557047694]            4950 N 21ST ST
# 68    [43.105909350137495, -87.96272433985564]            4873 N 40TH ST
# 70     [43.091434400278445, -87.9418904285996]            4112 N 24TH ST
# 71    [43.090900328888154, -87.94190719286189]            4074 N 24TH ST
# 72      [43.09930653666845, -87.9370260163368]            4556 N 20TH ST
# 78    [43.147731817370584, -87.96728202844207]            7144 N 44TH ST
# 79     [43.10683980761212, -87.95901887581971]            4921 N 37TH ST
# ...                                        ...                       ...
# 2808    [43.11943738762642, -87.9817340231059]   5540 W SILVER SPRING DR
# 2810  [43.177844686184415, -88.02471482253026]      9108 W BROWN DEER RD
# 2813   [43.14460648530218, -87.98688240979459]            6958 N 61ST ST
# 2826    [43.1517034906247, -87.98313473427982]         5700 W HEMLOCK ST
# 2837   [43.184170395148726, -88.0147420793827]      8405 W NORTHRIDGE CT
# 2840   [43.135365590650565, -88.0150323697473]       8311 W BRENTWOOD AV
# 2842    [43.1850508224386, -88.01698515404087]     8650 W FAIRY CHASM DR
# 2843   [43.182381017670934, -88.0280844230569]            9050 N 95TH ST
# 2847   [43.12557371285766, -87.98942116445443]            5940 N 63RD ST
# 2849    [43.18192522866747, -88.0329899613169]       8962 N 97TH ST #204
# 2858  [43.177613194394496, -88.02349757934905]      9025 W BROWN DEER RD
# 2859   [43.13434435291066, -87.98891607191842]            6415 N 62ND ST
# 2861    [43.1423693884376, -87.98556039739367]            6840 N 60TH ST
# 2874   [43.13532642607481, -88.00214434738297]            6450 N 73RD ST
# 2876   [43.13248352969225, -87.98604967445215]            6300 N 60TH ST
# 2885   [43.11925936143149, -87.97683659852942]   5151 W SILVER SPRING DR
# 2888   [43.11925500421614, -87.98383096962277]   5739 W SILVER SPRING DR
# 2889   [43.16267014381316, -88.00486015427191]            7965 N 76TH ST
# 2891    [43.17801196907823, -88.0031899072876]      7600 W BROWN DEER RD
# 2892  [43.141325173019425, -87.97707038628852]      5200 W GREEN TREE RD
# 2895  [43.137478930009706, -87.97945509967235]            6582 N 54TH ST
# 2897  [43.141646319123424, -87.98566174829028]            6815 N 60TH ST
# 2898     [43.1485602323699, -88.0024837407313]       7401 W GOOD HOPE RD
# 2902   [43.16026234753042, -87.97572933973646]            7867 N LINK PL
# 2903   [43.17021422190993, -88.03968143355053]           10313 W DEAN RD
# 2904   [43.11752873936092, -87.97632118897093]        5100 W SHERIDAN AV
# 2907      [43.13844101754, -88.01857474892478]            6651 N 85TH ST
# 2911  [43.148535099016726, -87.99961048413576]       7101 W GOOD HOPE RD
# 2914   [43.18397533849219, -88.00278906506253]            9084 N 75TH ST
# 2915  [43.121192724865466, -87.99022783204805]        6337 W THURSTON AV
#
# [943 rows x 9 columns]
