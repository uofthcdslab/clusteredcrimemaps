# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cluster-4.csv', sep=';')
df
# Out:
#        Cluster     White  Black or African American  \
# 0  Euclidean-0  0.481927                   0.436945
# 1   Geodesic-0  0.312484                   0.626666
# 2  Euclidean-1  0.649836                   0.065744
# 3   Geodesic-1  0.683277                   0.055374
# 4  Euclidean-2  0.280133                   0.594161
# 5   Geodesic-2  0.262209                   0.628280
# 6  Euclidean-3  0.230819                   0.685531
# 7   Geodesic-3  0.391436                   0.438295
#
#    American Indian or Alaskan Native     Asian  \
# 0                           0.004427  0.030320
# 1                           0.004015  0.014152
# 2                           0.014612  0.026230
# 3                           0.014042  0.024547
# 4                           0.004431  0.070510
# 5                           0.004597  0.056871
# 6                           0.004818  0.033784
# 7                           0.008106  0.053748
#
# ...
