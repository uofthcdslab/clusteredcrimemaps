# %%
import os
import subprocess
import warnings
import json
import calendar
import shapely
import pandas as pd
import geopandas as gpd
import numpy as np

from scipy.spatial.distance import cdist
from shapely.geometry import Point
from geopandas import GeoDataFrame

# %%
# KMeans Class Declaration
class KMeans(object):
    def __init__(self, k=8, distance = 'euclid'):
        self.k = k
        if (distance == 'euclid'):
            self._distance = 'euclidean'
        elif (distance == 'haversine'):
            self._distance = self._distance_haversine
        elif (distance == 'manhattan'):
            self._distance = self._distance_manhattan
        elif (distance == 'street'):
            self._distance = self._distance_street
        else:
            raise Exception('Invalid distance metric')
    
    def _step(self):
        """Compute distance, assign groups, recompute centers"""
        distance = cdist(self.X,self.cluster_centers,metric=self._distance)
        self.labels = distance.argmin(1)
       # centers = np.zeros((self.k,2))
        for cluster in range(self.k):
            points = self.X[self.labels == cluster]
            if len(points) == 0:
                distance = cdist(self.X,np.delete(self.cluster_centers,cluster,0),metric=self._distance)
                mean_dist = np.mean(distance,0)
                self.cluster_centers[cluster] = mean_dist.argmax()
            else:
                self.cluster_centers[cluster] = np.mean(points,0)
       # self.cluster_centers = centers
        
    def _distance_haversine(self,a,b):
        lat_1, lon_1, lat_2, lon_2 = map(np.radians,[a[0],a[1],b[0],b[1]])
        d_lat = lat_2 - lat_1
        d_lon = lon_2 - lon_1
        
        arc = np.sin(d_lat/2.0)**2 + np.cos(lat_1)*np.cos(lat_2)*np.sin(d_lon/2)**2
        
        c = 2 * np.arcsin(np.sqrt(arc))
        km = 6372.8 * c
        return km
    
    def _distance_manhattan(self, a, b):
        lat_1, lon_1, lat_2, lon_2 = map(np.radians,[a[0],a[1],b[0],b[1]])
        manhattanDistance = abs(lat_2 - lat_1) + abs(lon_2 - lon_1)
        return manhattanDistance
    
    def _distance_street(self, a, b):
        lat_1, lon_1, lat_2, lon_2 = map(np.radians,[a[0],a[1],b[0],b[1]])
        
        query = 'http://localhost:5000/route/v1/driving/%s,%s;%s,%s?overview=false' % (str(lon_1), str(loat_1), str(lon_2), str(lat_2))
        result = subprocess.run(["curl", query], stdout=subprocess.PIPE)
        resultStr = result.stdout.decode("utf-8")
        resultDict = json.loads(resultStr)
        streetDistance = resultDict['routes'][0]['distance']
        
        return streetDistance
   
    def _init_centers(self, X):
        unique = np.unique(X, axis=0)
        index = np.random.permutation(len(unique))[:self.k]
        return unique[index]
    
    def fit(self,X, centers = None):
        '''Expects centers to be inputted, if not random'''
        self.labels = np.zeros(len(X))
        self.X = X
        if centers is not None:
            self.cluster_centers = centers 
        else:
            self.cluster_centers = self._init_centers(X)
        old_centers = np.zeros((self.k,2))
    #    self.i = 0
        while(not np.array_equal(old_centers, self.cluster_centers)):
            old_centers = self.cluster_centers.copy()
            self._step()
         #   self.i+=1

# %%
def gen_coords(loc):
    data = loc[1:-1].split(',')
    data = list((np.float(data[0]), np.float(data[1])))
    x.append(data[1])
    y.append(data[0])
    return [data[0],data[1]]

def point_similarity(X,geo_labels, euc_labels,k):
    '''For an inputted series of points, geodesic labels, euclidean labels, and k-value
       returns the point-similarity index per geodesic cluster
    '''

    euc_cluster_totals = np.zeros(k,dtype=np.int)
    geo_euc_composition = [np.zeros(k,dtype=np.int)* 1 for i in range(k)]
    
    for index,point in enumerate(geo_labels):
        euc_cluster_totals[euc_labels[index]] += 1
        geo_euc_composition[point][euc_labels[index]] += 1
    
    point_sim = []
    for geo_cluster in range(k):
        sim = 0
        for euc_cluster in range(k):
            matching_points = geo_euc_composition[geo_cluster][euc_cluster]
            euc_percentage = matching_points / euc_cluster_totals[euc_cluster]
            geo_percentage = matching_points / np.sum(geo_euc_composition[geo_cluster])
            sim += euc_percentage * geo_percentage
        point_sim.append(sim)

    return np.array(point_sim)

def percent_similarity(a,b):
    return len(a[a==b])/len(a)

def minority_probability(X,cluster_number,geo_labels,demographics):
        points = X[geo_labels == cluster_number]
        # geoJSON puts points in Long/Lat order
        # but points are in lat/long earlier
        hull = shapely.geometry.multipoint.MultiPoint([[p[1],p[0]] for p in points]).convex_hull
  
        pop = np.zeros(7)
        for index in range(len(demographics)):
            census_tract = demographics.loc[index,'geometry']
            intersect = hull.intersection(census_tract)
            overlap = intersect.area/census_tract.area
            if (overlap != 0):
                pop = pop + (np.array(demographics.loc[index,['White','Black or African American', 'American Indian and Ala Native',
                   'Asian','Native Hawaiian/other Pac Isl', 'Multiple Race',
                   'Other Race']]) * overlap)
        
        if (np.all(pop ==0)):
            return 0
        
        return (pop[1:]/np.sum(pop)).sum()

def bias_index(X, geo_labels, euc_labels, demographics, k):
    if np.all(geo_labels == euc_labels):
        return 0

    dissimilarity_index = 1 - point_similarity(X,geo_labels,euc_labels,k)
    minority_prob = np.array([minority_probability(X,cluster,geo_labels,demographics) 
                              for cluster in range(k)])
    
    potential_bias = minority_prob * dissimilarity_index
    return potential_bias.mean()

# %%
def create_bias_matrix():
    columns = ['year', 'k']
    for crime in ['theft', 'mtheft', 'assault', 'robbery']:
        for month in calendar.month_abbr:
            if month != "":
                columns.append(crime + "_" + month.lower())

    frame_list = []
    for year in range(2005,2017):
        for k in range(2,11):
            year_list = [str(year)]
            year_list.append(k)
            year_list.extend([np.nan for i in range(48)])
            frame_list.append(year_list)

    bias_frame = pd.DataFrame(data=frame_list, columns=columns)

    return bias_frame

# %%
# update the bias matrix with one value
def store_bias(bias_value, bias_frame, year, monthNum, k, crime):
    year_array = np.array(bias_frame.year == str(year)) 
    k_array = np.array(bias_frame.k == k)
    row_index = np.logical_and(year_array,k_array)
    col_name = crime + "_" + calendar.month_abbr[monthNum].lower()

    bias_frame.at[row_index, col_name] = bias_value
    return bias_frame

# %%
# global variables
demographics = gpd.read_file('../resources/census.geoJSON')
dataDestination = '../data/clustered_data/'
dataSource = '../data/raw_data/'
bias_frame = create_bias_matrix()

rawDataList = os.listdir(dataSource)
rawDataList = [file for file in rawDataList if file.endswith('.csv')]
minK = 2
maxK = 10

# %%
for file in rawDataList:
    df = pd.read_csv(dataSource + file, sep =';')
    [year, monthNum, crime] = file[:-4].split("_")
    year = int(year)
    monthNum = int(monthNum)

    x = []
    y = []

    df['Points'] = df['Location'].apply(gen_coords)
    points = [Point(xy) for xy in zip(x,y)]
    crs = {'init': 'epsg:4326'}
    geo_df = GeoDataFrame(df,crs=crs, geometry=points)
    
    result = geo_df.copy()
    test_list = []

    for index in range(len(result)):
        test_list.append(df.loc[index, 'Points'])

    X = np.array(test_list)

    for k in range(minK ,maxK + 1):
        euclid = KMeans(k = k, distance = 'euclid')
        geodesic = KMeans(k = k, distance = 'haversine')
        manhattan = KMeans(k = k, distance = 'manhattan')

        centers = geodesic._init_centers(X)

        euclid.fit(X, centers = centers)
        geodesic.fit(X, centers = centers) 
        manhattan.fit(X, centers = centers)

        bias_GeodesicEuclid = bias_index(X, geodesic.labels, euclid.labels, demographics, k)
        bias_ManhattanGeodesic = bias_index(X, manhattan.labels, geodesic.labels, demographics, k)
        bias_ManhattanEuclid = bias_index(X, manhattan.labels, euclid.labels, demographics, k)

        bias_frame = store_bias(bias_GeodesicEuclid, bias_frame, year, monthNum, k, crime)
        bias_frame = store_bias(bias_ManhattanGeodesic, bias_frame, year, monthNum, k, crime)
        bias_frame = store_bias(bias_ManhattanEuclid, bias_frame, year, monthNum, k, crime)

        result.loc[:,'e_cluster' + 'K' + str(k)] = euclid.labels.copy()
        result.loc[:,'g_cluster' + 'K' + str(k)] = geodesic.labels.copy()
        result.loc[:,'m_cluster' + 'K' + str(k)] = manhattan.labels.copy()

    result = result.drop('Points', axis=1)

    resultFileName = dataDestination + file[:-4] + "_clustered.js"
    try:
        os.remove(resultFileName)
    except FileNotFoundError:
        pass

    result.to_file(resultFileName, driver='GeoJSON')
    print(resultFileName)
# Out:
# ../data/clustered_data/2005_01_assault_clustered.js
# ../data/clustered_data/2005_01_mtheft_clustered.js
# ../data/clustered_data/2005_01_robbery_clustered.js
# ../data/clustered_data/2005_01_theft_clustered.js
# ../data/clustered_data/2005_02_assault_clustered.js
# ../data/clustered_data/2005_02_mtheft_clustered.js
# ../data/clustered_data/2005_02_robbery_clustered.js
# ../data/clustered_data/2005_02_theft_clustered.js
# ../data/clustered_data/2005_03_assault_clustered.js
# ../data/clustered_data/2005_03_mtheft_clustered.js
# ../data/clustered_data/2005_03_robbery_clustered.js
# ../data/clustered_data/2005_03_theft_clustered.js
# ../data/clustered_data/2005_04_assault_clustered.js
# ../data/clustered_data/2005_04_mtheft_clustered.js
# ../data/clustered_data/2005_04_robbery_clustered.js
# ../data/clustered_data/2005_04_theft_clustered.js
# ../data/clustered_data/2005_05_assault_clustered.js
# ../data/clustered_data/2005_05_mtheft_clustered.js
# ../data/clustered_data/2005_05_robbery_clustered.js
# ../data/clustered_data/2005_05_theft_clustered.js
# ../data/clustered_data/2005_06_assault_clustered.js
# ../data/clustered_data/2005_06_mtheft_clustered.js
# ../data/clustered_data/2005_06_robbery_clustered.js
# ../data/clustered_data/2005_06_theft_clustered.js
# ../data/clustered_data/2005_07_assault_clustered.js
# ../data/clustered_data/2005_07_mtheft_clustered.js
# ../data/clustered_data/2005_07_robbery_clustered.js
# ../data/clustered_data/2005_07_theft_clustered.js
# ../data/clustered_data/2005_08_assault_clustered.js
# ../data/clustered_data/2005_08_mtheft_clustered.js
# ../data/clustered_data/2005_08_robbery_clustered.js
# ../data/clustered_data/2005_08_theft_clustered.js
# ../data/clustered_data/2005_09_assault_clustered.js
# ../data/clustered_data/2005_09_mtheft_clustered.js
# ../data/clustered_data/2005_09_robbery_clustered.js
# ../data/clustered_data/2005_09_theft_clustered.js
# ../data/clustered_data/2005_10_assault_clustered.js
# ../data/clustered_data/2005_10_mtheft_clustered.js
# ../data/clustered_data/2005_10_robbery_clustered.js
# ../data/clustered_data/2005_10_theft_clustered.js
# ../data/clustered_data/2005_11_assault_clustered.js
# ../data/clustered_data/2005_11_mtheft_clustered.js
# ../data/clustered_data/2005_11_robbery_clustered.js
# ../data/clustered_data/2005_11_theft_clustered.js
# ../data/clustered_data/2005_12_assault_clustered.js
# ../data/clustered_data/2005_12_mtheft_clustered.js
# ../data/clustered_data/2005_12_robbery_clustered.js
# ../data/clustered_data/2005_12_theft_clustered.js
# ../data/clustered_data/2006_01_assault_clustered.js
# ../data/clustered_data/2006_01_mtheft_clustered.js
# ../data/clustered_data/2006_01_robbery_clustered.js
# ../data/clustered_data/2006_01_theft_clustered.js
# ../data/clustered_data/2006_02_assault_clustered.js
# ../data/clustered_data/2006_02_mtheft_clustered.js
# ../data/clustered_data/2006_02_robbery_clustered.js
# ../data/clustered_data/2006_02_theft_clustered.js
# ../data/clustered_data/2006_03_assault_clustered.js
# ../data/clustered_data/2006_03_mtheft_clustered.js
# ../data/clustered_data/2006_03_robbery_clustered.js
# ../data/clustered_data/2006_03_theft_clustered.js
# ../data/clustered_data/2006_04_assault_clustered.js
# ../data/clustered_data/2006_04_mtheft_clustered.js
# ../data/clustered_data/2006_04_robbery_clustered.js
# ../data/clustered_data/2006_04_theft_clustered.js
# ../data/clustered_data/2006_05_assault_clustered.js
# ../data/clustered_data/2006_05_mtheft_clustered.js
# ../data/clustered_data/2006_05_robbery_clustered.js
# ../data/clustered_data/2006_05_theft_clustered.js
# ../data/clustered_data/2006_06_assault_clustered.js
# ../data/clustered_data/2006_06_mtheft_clustered.js
# ../data/clustered_data/2006_06_robbery_clustered.js
# ../data/clustered_data/2006_06_theft_clustered.js
# ../data/clustered_data/2006_07_assault_clustered.js
# ../data/clustered_data/2006_07_mtheft_clustered.js
# ../data/clustered_data/2006_07_robbery_clustered.js
# ../data/clustered_data/2006_07_theft_clustered.js
# ../data/clustered_data/2006_08_assault_clustered.js
# ../data/clustered_data/2006_08_mtheft_clustered.js
# ../data/clustered_data/2006_08_robbery_clustered.js
# ../data/clustered_data/2006_08_theft_clustered.js
# ../data/clustered_data/2006_09_assault_clustered.js
# ../data/clustered_data/2006_09_mtheft_clustered.js
# ../data/clustered_data/2006_09_robbery_clustered.js
# ../data/clustered_data/2006_09_theft_clustered.js
# ../data/clustered_data/2006_10_assault_clustered.js
# ../data/clustered_data/2006_10_mtheft_clustered.js
# ../data/clustered_data/2006_10_robbery_clustered.js
# ../data/clustered_data/2006_10_theft_clustered.js
# ../data/clustered_data/2006_11_assault_clustered.js
# ../data/clustered_data/2006_11_mtheft_clustered.js
# ../data/clustered_data/2006_11_robbery_clustered.js
# ../data/clustered_data/2006_11_theft_clustered.js
# ../data/clustered_data/2006_12_assault_clustered.js
# ../data/clustered_data/2006_12_mtheft_clustered.js
# ../data/clustered_data/2006_12_robbery_clustered.js
# ../data/clustered_data/2006_12_theft_clustered.js
# ../data/clustered_data/2007_01_assault_clustered.js
# ../data/clustered_data/2007_01_mtheft_clustered.js
# ../data/clustered_data/2007_01_robbery_clustered.js
# ../data/clustered_data/2007_01_theft_clustered.js
# ../data/clustered_data/2007_02_assault_clustered.js
# ../data/clustered_data/2007_02_mtheft_clustered.js
# ../data/clustered_data/2007_02_robbery_clustered.js
# ../data/clustered_data/2007_02_theft_clustered.js
# ../data/clustered_data/2007_03_assault_clustered.js
# ../data/clustered_data/2007_03_mtheft_clustered.js
# ../data/clustered_data/2007_03_robbery_clustered.js
# ../data/clustered_data/2007_03_theft_clustered.js
# ../data/clustered_data/2007_04_assault_clustered.js
# ../data/clustered_data/2007_04_mtheft_clustered.js
# ../data/clustered_data/2007_04_robbery_clustered.js
# ../data/clustered_data/2007_04_theft_clustered.js
# ../data/clustered_data/2007_05_assault_clustered.js
# ../data/clustered_data/2007_05_mtheft_clustered.js
# ../data/clustered_data/2007_05_robbery_clustered.js
# ../data/clustered_data/2007_05_theft_clustered.js
# ../data/clustered_data/2007_06_assault_clustered.js
# ../data/clustered_data/2007_06_mtheft_clustered.js
# ../data/clustered_data/2007_06_robbery_clustered.js
# ../data/clustered_data/2007_06_theft_clustered.js
# ../data/clustered_data/2007_07_assault_clustered.js
# ../data/clustered_data/2007_07_mtheft_clustered.js
# ../data/clustered_data/2007_07_robbery_clustered.js
# ../data/clustered_data/2007_07_theft_clustered.js
# ../data/clustered_data/2007_08_assault_clustered.js
# ../data/clustered_data/2007_08_mtheft_clustered.js
# ../data/clustered_data/2007_08_robbery_clustered.js
# ../data/clustered_data/2007_08_theft_clustered.js
# ../data/clustered_data/2007_09_assault_clustered.js
# ../data/clustered_data/2007_09_mtheft_clustered.js
# ../data/clustered_data/2007_09_robbery_clustered.js
# ../data/clustered_data/2007_09_theft_clustered.js
# ../data/clustered_data/2007_10_assault_clustered.js
# ../data/clustered_data/2007_10_mtheft_clustered.js
# ../data/clustered_data/2007_10_robbery_clustered.js
# ../data/clustered_data/2007_10_theft_clustered.js
# ../data/clustered_data/2007_11_assault_clustered.js
# ../data/clustered_data/2007_11_mtheft_clustered.js
# ../data/clustered_data/2007_11_robbery_clustered.js
# ../data/clustered_data/2007_11_theft_clustered.js
# ../data/clustered_data/2007_12_assault_clustered.js
# ../data/clustered_data/2007_12_mtheft_clustered.js
# ../data/clustered_data/2007_12_robbery_clustered.js
# ../data/clustered_data/2007_12_theft_clustered.js
# ../data/clustered_data/2008_01_assault_clustered.js
# ../data/clustered_data/2008_01_mtheft_clustered.js
# ../data/clustered_data/2008_01_robbery_clustered.js
# ../data/clustered_data/2008_01_theft_clustered.js
# ../data/clustered_data/2008_02_assault_clustered.js
# ../data/clustered_data/2008_02_mtheft_clustered.js
# ../data/clustered_data/2008_02_robbery_clustered.js
# ../data/clustered_data/2008_02_theft_clustered.js
# ../data/clustered_data/2008_03_assault_clustered.js
# ../data/clustered_data/2008_03_mtheft_clustered.js
# ../data/clustered_data/2008_03_robbery_clustered.js
# ../data/clustered_data/2008_03_theft_clustered.js
# ../data/clustered_data/2008_04_assault_clustered.js
# ../data/clustered_data/2008_04_mtheft_clustered.js
# ../data/clustered_data/2008_04_robbery_clustered.js
# ../data/clustered_data/2008_04_theft_clustered.js
# ../data/clustered_data/2008_05_assault_clustered.js
# ../data/clustered_data/2008_05_mtheft_clustered.js
# ../data/clustered_data/2008_05_robbery_clustered.js
# ../data/clustered_data/2008_05_theft_clustered.js
# ../data/clustered_data/2008_06_assault_clustered.js
# ../data/clustered_data/2008_06_mtheft_clustered.js
# ../data/clustered_data/2008_06_robbery_clustered.js
# ../data/clustered_data/2008_06_theft_clustered.js
# ../data/clustered_data/2008_07_assault_clustered.js
# ../data/clustered_data/2008_07_mtheft_clustered.js
# ../data/clustered_data/2008_07_robbery_clustered.js
# ../data/clustered_data/2008_07_theft_clustered.js
# ../data/clustered_data/2008_08_assault_clustered.js
# ../data/clustered_data/2008_08_mtheft_clustered.js
# ../data/clustered_data/2008_08_robbery_clustered.js
# ../data/clustered_data/2008_08_theft_clustered.js
# ../data/clustered_data/2008_09_assault_clustered.js
# ../data/clustered_data/2008_09_mtheft_clustered.js
# ../data/clustered_data/2008_09_robbery_clustered.js
# ../data/clustered_data/2008_09_theft_clustered.js
# ../data/clustered_data/2008_10_assault_clustered.js
# ../data/clustered_data/2008_10_mtheft_clustered.js
# ../data/clustered_data/2008_10_robbery_clustered.js
# ../data/clustered_data/2008_10_theft_clustered.js
# ../data/clustered_data/2008_11_assault_clustered.js
# ../data/clustered_data/2008_11_mtheft_clustered.js
# ../data/clustered_data/2008_11_robbery_clustered.js
# ../data/clustered_data/2008_11_theft_clustered.js
# ../data/clustered_data/2008_12_assault_clustered.js
# ../data/clustered_data/2008_12_mtheft_clustered.js
# ../data/clustered_data/2008_12_robbery_clustered.js
# ../data/clustered_data/2008_12_theft_clustered.js
# ../data/clustered_data/2009_01_assault_clustered.js
# ../data/clustered_data/2009_01_mtheft_clustered.js
# ../data/clustered_data/2009_01_robbery_clustered.js
# ../data/clustered_data/2009_01_theft_clustered.js
# ../data/clustered_data/2009_02_assault_clustered.js
# ../data/clustered_data/2009_02_mtheft_clustered.js
# ../data/clustered_data/2009_02_robbery_clustered.js
# ../data/clustered_data/2009_02_theft_clustered.js
# ../data/clustered_data/2009_03_assault_clustered.js
# ../data/clustered_data/2009_03_mtheft_clustered.js
# ../data/clustered_data/2009_03_robbery_clustered.js
# ../data/clustered_data/2009_03_theft_clustered.js
# ../data/clustered_data/2009_04_assault_clustered.js
# ../data/clustered_data/2009_04_mtheft_clustered.js
# ../data/clustered_data/2009_04_robbery_clustered.js
# ../data/clustered_data/2009_04_theft_clustered.js
# ../data/clustered_data/2009_05_assault_clustered.js
# ../data/clustered_data/2009_05_mtheft_clustered.js
# ../data/clustered_data/2009_05_robbery_clustered.js
# ../data/clustered_data/2009_05_theft_clustered.js
# ../data/clustered_data/2009_06_assault_clustered.js
# ../data/clustered_data/2009_06_mtheft_clustered.js
# ../data/clustered_data/2009_06_robbery_clustered.js
# ../data/clustered_data/2009_06_theft_clustered.js
# ../data/clustered_data/2009_07_assault_clustered.js
# ../data/clustered_data/2009_07_mtheft_clustered.js
# ../data/clustered_data/2009_07_robbery_clustered.js
# ../data/clustered_data/2009_07_theft_clustered.js
# ../data/clustered_data/2009_08_assault_clustered.js
# ../data/clustered_data/2009_08_mtheft_clustered.js
# ../data/clustered_data/2009_08_robbery_clustered.js
# ../data/clustered_data/2009_08_theft_clustered.js
# ../data/clustered_data/2009_09_assault_clustered.js
# ../data/clustered_data/2009_09_mtheft_clustered.js
# ../data/clustered_data/2009_09_robbery_clustered.js
# ../data/clustered_data/2009_09_theft_clustered.js
# ../data/clustered_data/2009_10_assault_clustered.js
# ../data/clustered_data/2009_10_mtheft_clustered.js
# ../data/clustered_data/2009_10_robbery_clustered.js
# ../data/clustered_data/2009_10_theft_clustered.js
# ../data/clustered_data/2009_11_assault_clustered.js
# ../data/clustered_data/2009_11_mtheft_clustered.js
# ../data/clustered_data/2009_11_robbery_clustered.js
# ../data/clustered_data/2009_11_theft_clustered.js
# ../data/clustered_data/2009_12_assault_clustered.js
# ../data/clustered_data/2009_12_mtheft_clustered.js
# ../data/clustered_data/2009_12_robbery_clustered.js
# ../data/clustered_data/2009_12_theft_clustered.js
# ../data/clustered_data/2010_01_assault_clustered.js
# ../data/clustered_data/2010_01_mtheft_clustered.js
# ../data/clustered_data/2010_01_robbery_clustered.js
# ../data/clustered_data/2010_01_theft_clustered.js
# ../data/clustered_data/2010_02_assault_clustered.js
# ../data/clustered_data/2010_02_mtheft_clustered.js
# ../data/clustered_data/2010_02_robbery_clustered.js
# ../data/clustered_data/2010_02_theft_clustered.js
# ../data/clustered_data/2010_03_assault_clustered.js
# ../data/clustered_data/2010_03_mtheft_clustered.js
# ../data/clustered_data/2010_03_robbery_clustered.js
# ../data/clustered_data/2010_03_theft_clustered.js
# ../data/clustered_data/2010_04_assault_clustered.js
# ../data/clustered_data/2010_04_mtheft_clustered.js
# ../data/clustered_data/2010_04_robbery_clustered.js
# ../data/clustered_data/2010_04_theft_clustered.js
# ../data/clustered_data/2010_05_assault_clustered.js
# ../data/clustered_data/2010_05_mtheft_clustered.js
# ../data/clustered_data/2010_05_robbery_clustered.js
# ../data/clustered_data/2010_05_theft_clustered.js
# ../data/clustered_data/2010_06_assault_clustered.js
# ../data/clustered_data/2010_06_mtheft_clustered.js
# ../data/clustered_data/2010_06_robbery_clustered.js
# ../data/clustered_data/2010_06_theft_clustered.js
# ../data/clustered_data/2010_07_assault_clustered.js
# ../data/clustered_data/2010_07_mtheft_clustered.js
# ../data/clustered_data/2010_07_robbery_clustered.js
# ../data/clustered_data/2010_07_theft_clustered.js
# ../data/clustered_data/2010_08_assault_clustered.js
# ../data/clustered_data/2010_08_mtheft_clustered.js
# ../data/clustered_data/2010_08_robbery_clustered.js
# ../data/clustered_data/2010_08_theft_clustered.js
# ../data/clustered_data/2010_09_assault_clustered.js
# ../data/clustered_data/2010_09_mtheft_clustered.js
# ../data/clustered_data/2010_09_robbery_clustered.js
# ../data/clustered_data/2010_09_theft_clustered.js
# ../data/clustered_data/2010_10_assault_clustered.js
# ../data/clustered_data/2010_10_mtheft_clustered.js
# ../data/clustered_data/2010_10_robbery_clustered.js
# ../data/clustered_data/2010_10_theft_clustered.js
# ../data/clustered_data/2010_11_assault_clustered.js
# ../data/clustered_data/2010_11_mtheft_clustered.js
# ../data/clustered_data/2010_11_robbery_clustered.js
# ../data/clustered_data/2010_11_theft_clustered.js
# ../data/clustered_data/2010_12_assault_clustered.js
# ../data/clustered_data/2010_12_mtheft_clustered.js
# ../data/clustered_data/2010_12_robbery_clustered.js
# ../data/clustered_data/2010_12_theft_clustered.js
# ../data/clustered_data/2011_01_assault_clustered.js
# ../data/clustered_data/2011_01_mtheft_clustered.js
# ../data/clustered_data/2011_01_robbery_clustered.js
# ../data/clustered_data/2011_01_theft_clustered.js
# ../data/clustered_data/2011_02_assault_clustered.js
# ../data/clustered_data/2011_02_mtheft_clustered.js
# ../data/clustered_data/2011_02_robbery_clustered.js
# ../data/clustered_data/2011_02_theft_clustered.js
# ../data/clustered_data/2011_03_assault_clustered.js
# ../data/clustered_data/2011_03_mtheft_clustered.js
# ../data/clustered_data/2011_03_robbery_clustered.js
# ../data/clustered_data/2011_03_theft_clustered.js
# ../data/clustered_data/2011_04_assault_clustered.js
# ../data/clustered_data/2011_04_mtheft_clustered.js
# ../data/clustered_data/2011_04_robbery_clustered.js
# ../data/clustered_data/2011_04_theft_clustered.js
# ../data/clustered_data/2011_05_assault_clustered.js
# ../data/clustered_data/2011_05_mtheft_clustered.js
# ../data/clustered_data/2011_05_robbery_clustered.js
# ../data/clustered_data/2011_05_theft_clustered.js
# ../data/clustered_data/2011_06_assault_clustered.js
# ../data/clustered_data/2011_06_mtheft_clustered.js
# ../data/clustered_data/2011_06_robbery_clustered.js
# ../data/clustered_data/2011_06_theft_clustered.js
# ../data/clustered_data/2011_07_assault_clustered.js
# ../data/clustered_data/2011_07_mtheft_clustered.js
# ../data/clustered_data/2011_07_robbery_clustered.js
# ../data/clustered_data/2011_07_theft_clustered.js
# ../data/clustered_data/2011_08_assault_clustered.js
# ../data/clustered_data/2011_08_mtheft_clustered.js
# ../data/clustered_data/2011_08_robbery_clustered.js
# ../data/clustered_data/2011_08_theft_clustered.js
# ../data/clustered_data/2011_09_assault_clustered.js
# ../data/clustered_data/2011_09_mtheft_clustered.js
# ../data/clustered_data/2011_09_robbery_clustered.js
# ../data/clustered_data/2011_09_theft_clustered.js
# ../data/clustered_data/2011_10_assault_clustered.js
# ../data/clustered_data/2011_10_mtheft_clustered.js
# ../data/clustered_data/2011_10_robbery_clustered.js
# ../data/clustered_data/2011_10_theft_clustered.js
# ../data/clustered_data/2011_11_assault_clustered.js
# ../data/clustered_data/2011_11_mtheft_clustered.js
# ../data/clustered_data/2011_11_robbery_clustered.js
# ../data/clustered_data/2011_11_theft_clustered.js
# ../data/clustered_data/2011_12_assault_clustered.js
# ../data/clustered_data/2011_12_mtheft_clustered.js
# ../data/clustered_data/2011_12_robbery_clustered.js
# ../data/clustered_data/2011_12_theft_clustered.js
# ../data/clustered_data/2012_01_assault_clustered.js
# ../data/clustered_data/2012_01_mtheft_clustered.js
# ../data/clustered_data/2012_01_robbery_clustered.js
# ../data/clustered_data/2012_01_theft_clustered.js
# ../data/clustered_data/2012_02_assault_clustered.js
# ../data/clustered_data/2012_02_mtheft_clustered.js
# ../data/clustered_data/2012_02_robbery_clustered.js
# ../data/clustered_data/2012_02_theft_clustered.js
# ../data/clustered_data/2012_03_assault_clustered.js
# ../data/clustered_data/2012_03_mtheft_clustered.js
# ../data/clustered_data/2012_03_robbery_clustered.js
# ../data/clustered_data/2012_03_theft_clustered.js
# ../data/clustered_data/2012_04_assault_clustered.js
# ../data/clustered_data/2012_04_mtheft_clustered.js
# ../data/clustered_data/2012_04_robbery_clustered.js
# ../data/clustered_data/2012_04_theft_clustered.js
# ../data/clustered_data/2012_05_assault_clustered.js
# ../data/clustered_data/2012_05_mtheft_clustered.js
# ../data/clustered_data/2012_05_robbery_clustered.js
# ../data/clustered_data/2012_05_theft_clustered.js
# ../data/clustered_data/2012_06_assault_clustered.js
# ../data/clustered_data/2012_06_mtheft_clustered.js
# ../data/clustered_data/2012_06_robbery_clustered.js
# ../data/clustered_data/2012_06_theft_clustered.js
# ../data/clustered_data/2012_07_assault_clustered.js
# ../data/clustered_data/2012_07_mtheft_clustered.js
# ../data/clustered_data/2012_07_robbery_clustered.js
# ../data/clustered_data/2012_07_theft_clustered.js
# ../data/clustered_data/2012_08_assault_clustered.js
# ../data/clustered_data/2012_08_mtheft_clustered.js
# ../data/clustered_data/2012_08_robbery_clustered.js
# ../data/clustered_data/2012_08_theft_clustered.js
# ../data/clustered_data/2012_09_assault_clustered.js
# ../data/clustered_data/2012_09_mtheft_clustered.js
# ../data/clustered_data/2012_09_robbery_clustered.js
# ../data/clustered_data/2012_09_theft_clustered.js
# ../data/clustered_data/2012_10_assault_clustered.js
# ../data/clustered_data/2012_10_mtheft_clustered.js
# ../data/clustered_data/2012_10_robbery_clustered.js
# ../data/clustered_data/2012_10_theft_clustered.js
# ../data/clustered_data/2012_11_assault_clustered.js
# ../data/clustered_data/2012_11_mtheft_clustered.js
# ../data/clustered_data/2012_11_robbery_clustered.js
# ../data/clustered_data/2012_11_theft_clustered.js
# ../data/clustered_data/2012_12_assault_clustered.js
# ../data/clustered_data/2012_12_mtheft_clustered.js
# ../data/clustered_data/2012_12_robbery_clustered.js
# ../data/clustered_data/2012_12_theft_clustered.js
# ../data/clustered_data/2013_01_assault_clustered.js
# ../data/clustered_data/2013_01_mtheft_clustered.js
# ../data/clustered_data/2013_01_robbery_clustered.js
# ../data/clustered_data/2013_01_theft_clustered.js
# ../data/clustered_data/2013_02_assault_clustered.js
# ../data/clustered_data/2013_02_mtheft_clustered.js
# ../data/clustered_data/2013_02_robbery_clustered.js
# ../data/clustered_data/2013_02_theft_clustered.js
# ../data/clustered_data/2013_03_assault_clustered.js
# ../data/clustered_data/2013_03_mtheft_clustered.js
# ../data/clustered_data/2013_03_robbery_clustered.js
# ../data/clustered_data/2013_03_theft_clustered.js
# ../data/clustered_data/2013_04_assault_clustered.js
# ../data/clustered_data/2013_04_mtheft_clustered.js
# ../data/clustered_data/2013_04_robbery_clustered.js
# ../data/clustered_data/2013_04_theft_clustered.js
# ../data/clustered_data/2013_05_assault_clustered.js
# ../data/clustered_data/2013_05_mtheft_clustered.js
# ../data/clustered_data/2013_05_robbery_clustered.js
# ../data/clustered_data/2013_05_theft_clustered.js
# ../data/clustered_data/2013_06_assault_clustered.js
# ../data/clustered_data/2013_06_mtheft_clustered.js
# ../data/clustered_data/2013_06_robbery_clustered.js
# ../data/clustered_data/2013_06_theft_clustered.js
# ../data/clustered_data/2013_07_assault_clustered.js
# ../data/clustered_data/2013_07_mtheft_clustered.js
# ../data/clustered_data/2013_07_robbery_clustered.js
# ../data/clustered_data/2013_07_theft_clustered.js
# ../data/clustered_data/2013_08_assault_clustered.js
# ../data/clustered_data/2013_08_mtheft_clustered.js
# ../data/clustered_data/2013_08_robbery_clustered.js
# ../data/clustered_data/2013_08_theft_clustered.js
# ../data/clustered_data/2013_09_assault_clustered.js
# ../data/clustered_data/2013_09_mtheft_clustered.js
# ../data/clustered_data/2013_09_robbery_clustered.js
# ../data/clustered_data/2013_09_theft_clustered.js
# ../data/clustered_data/2013_10_assault_clustered.js
# ../data/clustered_data/2013_10_mtheft_clustered.js
# ../data/clustered_data/2013_10_robbery_clustered.js
# ../data/clustered_data/2013_10_theft_clustered.js
# ../data/clustered_data/2013_11_assault_clustered.js
# ../data/clustered_data/2013_11_mtheft_clustered.js
# ../data/clustered_data/2013_11_robbery_clustered.js
# ../data/clustered_data/2013_11_theft_clustered.js
# ../data/clustered_data/2013_12_assault_clustered.js
# ../data/clustered_data/2013_12_mtheft_clustered.js
# ../data/clustered_data/2013_12_robbery_clustered.js
# ../data/clustered_data/2013_12_theft_clustered.js
# ../data/clustered_data/2014_01_assault_clustered.js
# ../data/clustered_data/2014_01_mtheft_clustered.js
# ../data/clustered_data/2014_01_robbery_clustered.js
# ../data/clustered_data/2014_01_theft_clustered.js
# ../data/clustered_data/2014_02_assault_clustered.js
# ../data/clustered_data/2014_02_mtheft_clustered.js
# ../data/clustered_data/2014_02_robbery_clustered.js
# ../data/clustered_data/2014_02_theft_clustered.js
# ../data/clustered_data/2014_03_assault_clustered.js
# ../data/clustered_data/2014_03_mtheft_clustered.js
# ../data/clustered_data/2014_03_robbery_clustered.js
# ../data/clustered_data/2014_03_theft_clustered.js
# ../data/clustered_data/2014_04_assault_clustered.js
# ../data/clustered_data/2014_04_mtheft_clustered.js
# ../data/clustered_data/2014_04_robbery_clustered.js
# ../data/clustered_data/2014_04_theft_clustered.js
# ../data/clustered_data/2014_05_assault_clustered.js
# ../data/clustered_data/2014_05_mtheft_clustered.js
# ../data/clustered_data/2014_05_robbery_clustered.js
# ../data/clustered_data/2014_05_theft_clustered.js
# ../data/clustered_data/2014_06_assault_clustered.js
# ../data/clustered_data/2014_06_mtheft_clustered.js
# ../data/clustered_data/2014_06_robbery_clustered.js
# ../data/clustered_data/2014_06_theft_clustered.js
# ../data/clustered_data/2014_07_assault_clustered.js
# ../data/clustered_data/2014_07_mtheft_clustered.js
# ../data/clustered_data/2014_07_robbery_clustered.js
# ../data/clustered_data/2014_07_theft_clustered.js
# ../data/clustered_data/2014_08_assault_clustered.js
# ../data/clustered_data/2014_08_mtheft_clustered.js
# ../data/clustered_data/2014_08_robbery_clustered.js
# ../data/clustered_data/2014_08_theft_clustered.js
# ../data/clustered_data/2014_09_assault_clustered.js
# ../data/clustered_data/2014_09_mtheft_clustered.js
# ../data/clustered_data/2014_09_robbery_clustered.js
# ../data/clustered_data/2014_09_theft_clustered.js
# ../data/clustered_data/2014_10_assault_clustered.js
# ../data/clustered_data/2014_10_mtheft_clustered.js
# ../data/clustered_data/2014_10_robbery_clustered.js
# ../data/clustered_data/2014_10_theft_clustered.js
# ../data/clustered_data/2014_11_assault_clustered.js
# ../data/clustered_data/2014_11_mtheft_clustered.js
# ../data/clustered_data/2014_11_robbery_clustered.js
# ../data/clustered_data/2014_11_theft_clustered.js
# ../data/clustered_data/2014_12_assault_clustered.js
# ../data/clustered_data/2014_12_mtheft_clustered.js
# ../data/clustered_data/2014_12_robbery_clustered.js
# ../data/clustered_data/2014_12_theft_clustered.js
# ../data/clustered_data/2015_01_assault_clustered.js
# ../data/clustered_data/2015_01_mtheft_clustered.js
# ../data/clustered_data/2015_01_robbery_clustered.js
# ../data/clustered_data/2015_01_theft_clustered.js
# ../data/clustered_data/2015_02_assault_clustered.js
# ../data/clustered_data/2015_02_mtheft_clustered.js
# ../data/clustered_data/2015_02_robbery_clustered.js
# ../data/clustered_data/2015_02_theft_clustered.js
# ../data/clustered_data/2015_03_assault_clustered.js
# ../data/clustered_data/2015_03_mtheft_clustered.js
# ../data/clustered_data/2015_03_robbery_clustered.js
# ../data/clustered_data/2015_03_theft_clustered.js
# ../data/clustered_data/2015_04_assault_clustered.js
# ../data/clustered_data/2015_04_mtheft_clustered.js
# ../data/clustered_data/2015_04_robbery_clustered.js
# ../data/clustered_data/2015_04_theft_clustered.js
# ../data/clustered_data/2015_05_assault_clustered.js
# ../data/clustered_data/2015_05_mtheft_clustered.js
# ../data/clustered_data/2015_05_robbery_clustered.js
# ../data/clustered_data/2015_05_theft_clustered.js
# ../data/clustered_data/2015_06_assault_clustered.js
# ../data/clustered_data/2015_06_mtheft_clustered.js
# ../data/clustered_data/2015_06_robbery_clustered.js
# ../data/clustered_data/2015_06_theft_clustered.js
# ../data/clustered_data/2015_07_assault_clustered.js
# ../data/clustered_data/2015_07_mtheft_clustered.js
# ../data/clustered_data/2015_07_robbery_clustered.js
# ../data/clustered_data/2015_07_theft_clustered.js
# ../data/clustered_data/2015_08_assault_clustered.js
# ../data/clustered_data/2015_08_mtheft_clustered.js
# ../data/clustered_data/2015_08_robbery_clustered.js
# ../data/clustered_data/2015_08_theft_clustered.js
# ../data/clustered_data/2015_09_assault_clustered.js
# ../data/clustered_data/2015_09_mtheft_clustered.js
# ../data/clustered_data/2015_09_robbery_clustered.js
# ../data/clustered_data/2015_09_theft_clustered.js
# ../data/clustered_data/2015_10_assault_clustered.js
# ../data/clustered_data/2015_10_mtheft_clustered.js
# ../data/clustered_data/2015_10_robbery_clustered.js
# ../data/clustered_data/2015_10_theft_clustered.js
# ../data/clustered_data/2015_11_assault_clustered.js
# ../data/clustered_data/2015_11_mtheft_clustered.js
# ../data/clustered_data/2015_11_robbery_clustered.js
# ../data/clustered_data/2015_11_theft_clustered.js
# ../data/clustered_data/2015_12_assault_clustered.js
# ../data/clustered_data/2015_12_mtheft_clustered.js
# ../data/clustered_data/2015_12_robbery_clustered.js
# ../data/clustered_data/2015_12_theft_clustered.js
# ../data/clustered_data/2016_01_assault_clustered.js
# ../data/clustered_data/2016_01_mtheft_clustered.js
# ../data/clustered_data/2016_01_robbery_clustered.js
# ../data/clustered_data/2016_01_theft_clustered.js
# ../data/clustered_data/2016_02_assault_clustered.js
# ../data/clustered_data/2016_02_mtheft_clustered.js
# ../data/clustered_data/2016_02_robbery_clustered.js
# ../data/clustered_data/2016_02_theft_clustered.js
# ../data/clustered_data/2016_03_assault_clustered.js
# ../data/clustered_data/2016_03_mtheft_clustered.js
# ../data/clustered_data/2016_03_robbery_clustered.js
# ../data/clustered_data/2016_03_theft_clustered.js
# ../data/clustered_data/2016_04_assault_clustered.js
# ../data/clustered_data/2016_04_mtheft_clustered.js
# ../data/clustered_data/2016_04_robbery_clustered.js
# ../data/clustered_data/2016_04_theft_clustered.js
# ../data/clustered_data/2016_05_assault_clustered.js
# ../data/clustered_data/2016_05_mtheft_clustered.js
# ../data/clustered_data/2016_05_robbery_clustered.js
# ../data/clustered_data/2016_05_theft_clustered.js
# ../data/clustered_data/2016_06_assault_clustered.js
# ../data/clustered_data/2016_06_mtheft_clustered.js
# ../data/clustered_data/2016_06_robbery_clustered.js
# ../data/clustered_data/2016_06_theft_clustered.js
# ../data/clustered_data/2016_07_assault_clustered.js
# ../data/clustered_data/2016_07_mtheft_clustered.js
# ../data/clustered_data/2016_07_robbery_clustered.js
# ../data/clustered_data/2016_07_theft_clustered.js
# ../data/clustered_data/2016_08_assault_clustered.js
# ../data/clustered_data/2016_08_mtheft_clustered.js
# ../data/clustered_data/2016_08_robbery_clustered.js
# ../data/clustered_data/2016_08_theft_clustered.js
# ../data/clustered_data/2016_09_assault_clustered.js
# ../data/clustered_data/2016_09_mtheft_clustered.js
# ../data/clustered_data/2016_09_robbery_clustered.js
# ../data/clustered_data/2016_09_theft_clustered.js
# ../data/clustered_data/2016_10_assault_clustered.js
# ../data/clustered_data/2016_10_mtheft_clustered.js
# ../data/clustered_data/2016_10_robbery_clustered.js
# ../data/clustered_data/2016_10_theft_clustered.js
# ../data/clustered_data/2016_11_assault_clustered.js
# ../data/clustered_data/2016_11_mtheft_clustered.js
# ../data/clustered_data/2016_11_robbery_clustered.js
# ../data/clustered_data/2016_11_theft_clustered.js
# ../data/clustered_data/2016_12_assault_clustered.js
# ../data/clustered_data/2016_12_mtheft_clustered.js
# ../data/clustered_data/2016_12_robbery_clustered.js
# ../data/clustered_data/2016_12_theft_clustered.js

# %%
biasFile = '../data/bias_data/bias.js'
biasJSON = bias_frame.to_json(orient='records')
with open(biasFile,'w') as w:
    w.write('var bias_data =' + biasJSON + ';')

# %%
#fix .js files to have var names
path = "../data/clustered_data/"
allFiles = os.listdir(path)

for file in allFiles:
    fileParts = file.split("_")
    varName = fileParts[2] + "_" + fileParts[0] + "_" + fileParts[1]
    print(varName)
    data = 'var ' + varName + ' = ['
    reader = open(path + file, 'r')
    data += (reader.read() + ',')
    data += '];'
    reader.close
    
    writer = open(path + file, 'w')
    writer.write(data)
    writer.close()
# Out:
# mtheft_2005_01
# robbery_2005_01
# theft_2005_01
# assault_2005_02
# mtheft_2005_02
# robbery_2005_02
# theft_2005_02
# assault_2005_03
# mtheft_2005_03
# robbery_2005_03
# theft_2005_03
# assault_2005_04
# mtheft_2005_04
# robbery_2005_04
# theft_2005_04
# assault_2005_05
# mtheft_2005_05
# robbery_2005_05
# theft_2005_05
# assault_2005_06
# mtheft_2005_06
# robbery_2005_06
# theft_2005_06
# assault_2005_07
# mtheft_2005_07
# robbery_2005_07
# theft_2005_07
# assault_2005_08
# mtheft_2005_08
# robbery_2005_08
# theft_2005_08
# assault_2005_09
# mtheft_2005_09
# robbery_2005_09
# theft_2005_09
# assault_2005_10
# mtheft_2005_10
# robbery_2005_10
# theft_2005_10
# assault_2005_11
# mtheft_2005_11
# robbery_2005_11
# theft_2005_11
# assault_2005_12
# mtheft_2005_12
# robbery_2005_12
# theft_2005_12
# assault_2006_01
# mtheft_2006_01
# robbery_2006_01
# theft_2006_01
# assault_2006_02
# mtheft_2006_02
# robbery_2006_02
# theft_2006_02
# assault_2006_03
# mtheft_2006_03
# robbery_2006_03
# theft_2006_03
# assault_2006_04
# mtheft_2006_04
# robbery_2006_04
# theft_2006_04
# assault_2006_05
# mtheft_2006_05
# robbery_2006_05
# theft_2006_05
# assault_2006_06
# mtheft_2006_06
# robbery_2006_06
# theft_2006_06
# assault_2006_07
# mtheft_2006_07
# robbery_2006_07
# theft_2006_07
# assault_2006_08
# mtheft_2006_08
# robbery_2006_08
# theft_2006_08
# assault_2006_09
# mtheft_2006_09
# robbery_2006_09
# theft_2006_09
# assault_2006_10
# mtheft_2006_10
# robbery_2006_10
# theft_2006_10
# assault_2006_11
# mtheft_2006_11
# robbery_2006_11
# theft_2006_11
# assault_2006_12
# mtheft_2006_12
# robbery_2006_12
# theft_2006_12
# assault_2007_01
# mtheft_2007_01
# robbery_2007_01
# theft_2007_01
# assault_2007_02
# mtheft_2007_02
# robbery_2007_02
# theft_2007_02
# assault_2007_03
# mtheft_2007_03
# robbery_2007_03
# theft_2007_03
# assault_2007_04
# mtheft_2007_04
# robbery_2007_04
# theft_2007_04
# assault_2007_05
# mtheft_2007_05
# robbery_2007_05
# theft_2007_05
# assault_2007_06
# mtheft_2007_06
# robbery_2007_06
# theft_2007_06
# assault_2007_07
# mtheft_2007_07
# robbery_2007_07
# theft_2007_07
# assault_2007_08
# mtheft_2007_08
# robbery_2007_08
# theft_2007_08
# assault_2007_09
# mtheft_2007_09
# robbery_2007_09
# theft_2007_09
# assault_2007_10
# mtheft_2007_10
# robbery_2007_10
# theft_2007_10
# assault_2007_11
# mtheft_2007_11
# robbery_2007_11
# theft_2007_11
# assault_2007_12
# mtheft_2007_12
# robbery_2007_12
# theft_2007_12
# assault_2008_01
# mtheft_2008_01
# robbery_2008_01
# theft_2008_01
# assault_2008_02
# mtheft_2008_02
# robbery_2008_02
# theft_2008_02
# assault_2008_03
# mtheft_2008_03
# robbery_2008_03
# theft_2008_03
# assault_2008_04
# mtheft_2008_04
# robbery_2008_04
# theft_2008_04
# assault_2008_05
# mtheft_2008_05
# robbery_2008_05
# theft_2008_05
# assault_2008_06
# mtheft_2008_06
# robbery_2008_06
# theft_2008_06
# assault_2008_07
# mtheft_2008_07
# robbery_2008_07
# theft_2008_07
# assault_2008_08
# mtheft_2008_08
# robbery_2008_08
# theft_2008_08
# assault_2008_09
# mtheft_2008_09
# robbery_2008_09
# theft_2008_09
# assault_2008_10
# mtheft_2008_10
# robbery_2008_10
# theft_2008_10
# assault_2008_11
# mtheft_2008_11
# robbery_2008_11
# theft_2008_11
# assault_2008_12
# mtheft_2008_12
# robbery_2008_12
# theft_2008_12
# assault_2009_01
# mtheft_2009_01
# robbery_2009_01
# theft_2009_01
# assault_2009_02
# mtheft_2009_02
# robbery_2009_02
# theft_2009_02
# assault_2009_03
# mtheft_2009_03
# robbery_2009_03
# theft_2009_03
# assault_2009_04
# mtheft_2009_04
# robbery_2009_04
# theft_2009_04
# assault_2009_05
# mtheft_2009_05
# robbery_2009_05
# theft_2009_05
# assault_2009_06
# mtheft_2009_06
# robbery_2009_06
# theft_2009_06
# assault_2009_07
# mtheft_2009_07
# robbery_2009_07
# theft_2009_07
# assault_2009_08
# mtheft_2009_08
# robbery_2009_08
# theft_2009_08
# assault_2009_09
# mtheft_2009_09
# robbery_2009_09
# theft_2009_09
# assault_2009_10
# mtheft_2009_10
# robbery_2009_10
# theft_2009_10
# assault_2009_11
# mtheft_2009_11
# robbery_2009_11
# theft_2009_11
# assault_2009_12
# mtheft_2009_12
# robbery_2009_12
# theft_2009_12
# assault_2010_01
# mtheft_2010_01
# robbery_2010_01
# theft_2010_01
# assault_2010_02
# mtheft_2010_02
# robbery_2010_02
# theft_2010_02
# assault_2010_03
# mtheft_2010_03
# robbery_2010_03
# theft_2010_03
# assault_2010_04
# mtheft_2010_04
# robbery_2010_04
# theft_2010_04
# assault_2010_05
# mtheft_2010_05
# robbery_2010_05
# theft_2010_05
# assault_2010_06
# mtheft_2010_06
# robbery_2010_06
# theft_2010_06
# assault_2010_07
# mtheft_2010_07
# robbery_2010_07
# theft_2010_07
# assault_2010_08
# mtheft_2010_08
# robbery_2010_08
# theft_2010_08
# assault_2010_09
# mtheft_2010_09
# robbery_2010_09
# theft_2010_09
# assault_2010_10
# mtheft_2010_10
# robbery_2010_10
# theft_2010_10
# assault_2010_11
# mtheft_2010_11
# robbery_2010_11
# theft_2010_11
# assault_2010_12
# mtheft_2010_12
# robbery_2010_12
# theft_2010_12
# assault_2011_01
# mtheft_2011_01
# robbery_2011_01
# theft_2011_01
# assault_2011_02
# mtheft_2011_02
# robbery_2011_02
# theft_2011_02
# assault_2011_03
# mtheft_2011_03
# robbery_2011_03
# theft_2011_03
# assault_2011_04
# mtheft_2011_04
# robbery_2011_04
# theft_2011_04
# assault_2011_05
# mtheft_2011_05
# robbery_2011_05
# theft_2011_05
# assault_2011_06
# mtheft_2011_06
# robbery_2011_06
# theft_2011_06
# assault_2011_07
# mtheft_2011_07
# robbery_2011_07
# theft_2011_07
# assault_2011_08
# mtheft_2011_08
# robbery_2011_08
# theft_2011_08
# assault_2011_09
# mtheft_2011_09
# robbery_2011_09
# theft_2011_09
# assault_2011_10
# mtheft_2011_10
# robbery_2011_10
# theft_2011_10
# assault_2011_11
# mtheft_2011_11
# robbery_2011_11
# theft_2011_11
# assault_2011_12
# mtheft_2011_12
# robbery_2011_12
# theft_2011_12
# assault_2012_01
# mtheft_2012_01
# robbery_2012_01
# theft_2012_01
# assault_2012_02
# mtheft_2012_02
# robbery_2012_02
# theft_2012_02
# assault_2012_03
# mtheft_2012_03
# robbery_2012_03
# theft_2012_03
# assault_2012_04
# mtheft_2012_04
# robbery_2012_04
# theft_2012_04
# assault_2012_05
# mtheft_2012_05
# robbery_2012_05
# theft_2012_05
# assault_2012_06
# mtheft_2012_06
# robbery_2012_06
# theft_2012_06
# assault_2012_07
# mtheft_2012_07
# robbery_2012_07
# theft_2012_07
# assault_2012_08
# mtheft_2012_08
# robbery_2012_08
# theft_2012_08
# assault_2012_09
# mtheft_2012_09
# robbery_2012_09
# theft_2012_09
# assault_2012_10
# mtheft_2012_10
# robbery_2012_10
# theft_2012_10
# assault_2012_11
# mtheft_2012_11
# robbery_2012_11
# theft_2012_11
# assault_2012_12
# mtheft_2012_12
# robbery_2012_12
# theft_2012_12
# assault_2013_01
# mtheft_2013_01
# robbery_2013_01
# theft_2013_01
# assault_2013_02
# mtheft_2013_02
# robbery_2013_02
# theft_2013_02
# assault_2013_03
# mtheft_2013_03
# robbery_2013_03
# theft_2013_03
# assault_2013_04
# mtheft_2013_04
# robbery_2013_04
# theft_2013_04
# assault_2013_05
# mtheft_2013_05
# robbery_2013_05
# theft_2013_05
# assault_2013_06
# mtheft_2013_06
# robbery_2013_06
# theft_2013_06
# assault_2013_07
# mtheft_2013_07
# robbery_2013_07
# theft_2013_07
# assault_2013_08
# mtheft_2013_08
# robbery_2013_08
# theft_2013_08
# assault_2013_09
# mtheft_2013_09
# robbery_2013_09
# theft_2013_09
# assault_2013_10
# mtheft_2013_10
# robbery_2013_10
# theft_2013_10
# assault_2013_11
# mtheft_2013_11
# robbery_2013_11
# theft_2013_11
# assault_2013_12
# mtheft_2013_12
# robbery_2013_12
# theft_2013_12
# assault_2014_01
# mtheft_2014_01
# robbery_2014_01
# theft_2014_01
# assault_2014_02
# mtheft_2014_02
# robbery_2014_02
# theft_2014_02
# assault_2014_03
# mtheft_2014_03
# robbery_2014_03
# theft_2014_03
# assault_2014_04
# mtheft_2014_04
# robbery_2014_04
# theft_2014_04
# assault_2014_05
# mtheft_2014_05
# robbery_2014_05
# theft_2014_05
# assault_2014_06
# mtheft_2014_06
# robbery_2014_06
# theft_2014_06
# assault_2014_07
# mtheft_2014_07
# robbery_2014_07
# theft_2014_07
# assault_2014_08
# mtheft_2014_08
# robbery_2014_08
# theft_2014_08
# assault_2014_09
# mtheft_2014_09
# robbery_2014_09
# theft_2014_09
# assault_2014_10
# mtheft_2014_10
# robbery_2014_10
# theft_2014_10
# assault_2014_11
# mtheft_2014_11
# robbery_2014_11
# theft_2014_11
# assault_2014_12
# mtheft_2014_12
# robbery_2014_12
# theft_2014_12
# assault_2015_01
# mtheft_2015_01
# robbery_2015_01
# theft_2015_01
# assault_2015_02
# mtheft_2015_02
# robbery_2015_02
# theft_2015_02
# assault_2015_03
# mtheft_2015_03
# robbery_2015_03
# theft_2015_03
# assault_2015_04
# mtheft_2015_04
# robbery_2015_04
# theft_2015_04
# assault_2015_05
# mtheft_2015_05
# robbery_2015_05
# theft_2015_05
# assault_2015_06
# mtheft_2015_06
# robbery_2015_06
# theft_2015_06
# assault_2015_07
# mtheft_2015_07
# robbery_2015_07
# theft_2015_07
# assault_2015_08
# mtheft_2015_08
# robbery_2015_08
# theft_2015_08
# assault_2015_09
# mtheft_2015_09
# robbery_2015_09
# theft_2015_09
# assault_2015_10
# mtheft_2015_10
# robbery_2015_10
# theft_2015_10
# assault_2015_11
# mtheft_2015_11
# robbery_2015_11
# theft_2015_11
# assault_2015_12
# mtheft_2015_12
# robbery_2015_12
# theft_2015_12
# assault_2016_01
# mtheft_2016_01
# robbery_2016_01
# theft_2016_01
# assault_2016_02
# mtheft_2016_02
# robbery_2016_02
# theft_2016_02
# assault_2016_03
# mtheft_2016_03
# robbery_2016_03
# theft_2016_03
# assault_2016_04
# mtheft_2016_04
# robbery_2016_04
# theft_2016_04
# assault_2016_05
# mtheft_2016_05
# robbery_2016_05
# theft_2016_05
# assault_2016_06
# mtheft_2016_06
# robbery_2016_06
# theft_2016_06
# assault_2016_07
# mtheft_2016_07
# robbery_2016_07
# theft_2016_07
# assault_2016_08
# mtheft_2016_08
# robbery_2016_08
# theft_2016_08
# assault_2016_09
# mtheft_2016_09
# robbery_2016_09
# theft_2016_09
# assault_2016_10
# mtheft_2016_10
# robbery_2016_10
# theft_2016_10
# assault_2016_11
# mtheft_2016_11
# robbery_2016_11
# theft_2016_11
# assault_2016_12
# mtheft_2016_12
# robbery_2016_12
# theft_2016_12
